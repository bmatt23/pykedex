# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import re
import requests
from urllib.request import urlopen
import time
from itertools import chain

# %%
poke_df = pd.read_pickle('poke_df.pkl')

# %%
poke_df.Pokemon.unique()
# Out:
# array(['Bulbasaur', 'Ivysaur', 'Venusaur', ..., 'Iron Valiant',
#        'Koraidon', 'Miraidon'], dtype=object)

# %% [markdown]
# Check which url's exist and which we need to modify

# %% [markdown]
# A lot of these names specify the "form" the pokemon is in, so if it fail and ends in form, let's only try the first word in it.

# %%
for pokemon in poke_df.Pokemon.unique():
    response = requests.get(f'https://pokemon.fandom.com/wiki/{pokemon}')
    if response.status_code == 200:
        pass
    else:
        # try just the first word
        if requests.get(
            f'https://pokemon.fandom.com/wiki/{pokemon.split()[0]}'
            ).status_code != 200:
            print(f"URL doesn't match for {pokemon} or its first word")
# Out:
# URL doesn't match for Ho-oh or its first word

# %% [markdown]
# There is only one URL we don't like there, and that's for Ho-oh. The correct URL is "Ho-Oh", so let's just fix that.

# %%
poke_df['url_poke'] = np.where(
    poke_df['Pokemon'] == 'Ho-oh', 'Ho-Oh', poke_df['Pokemon'])

# %% [markdown]
# Just to check here...

# %%
set(poke_df['url_poke']).difference(set(poke_df['Pokemon']))
# Out:
# {'Ho-Oh'}

# %% [markdown]
# Create dataframes

# %%
behavior_df = pd.DataFrame()
physiology_df = pd.DataFrame()
failed_pokemon = []

for pokemon in poke_df.url_poke.unique():

    url = f'https://pokemon.fandom.com/wiki/{pokemon}'

    # if we only want the first word of the pokemon make it so
    if requests.get(url).status_code == 200:
        url = f'https://pokemon.fandom.com/wiki/{pokemon.split()[0]}'

    try: 
        soup = BeautifulSoup(urlopen(
        url.encode('ascii', 'ignore').decode('utf-8')
        ).read(),'lxml')


        # first, the behavior
        temp_behavior_df = pd.DataFrame()
        poketext_behavior = []
        for tag in soup.find_all('h3')[1:]:
            if tag.text.strip() == 'Behavior':
                for item in tag.find_next_siblings('p'):
                    if 'Behavior' in item.find_previous_siblings('h3')[0].text.strip():
                        poketext_behavior.append(item.text.strip())
        if poketext_behavior:                
        # we want a new entry for each sentence.
            poketext_behavior = list(filter(None, list(chain(*[text.split('.') for text in poketext_behavior]))))
            temp_behavior_df['Pokemon'] = [pokemon] * len(poketext_behavior)
            temp_behavior_df['Behavior'] = poketext_behavior

            behavior_df = pd.concat([behavior_df,temp_behavior_df])
        else:
            print(f'no text found for behavior for {pokemon}')
            
        # now, the physiology
        temp_physiology_df = pd.DataFrame()
        poketext_physiology = []
        for tag in soup.find_all('h3')[1:]:
            if tag.text.strip() == 'Physiology':
                for item in tag.find_next_siblings('p'):
                    if 'Physiology' in item.find_previous_siblings('h3')[0].text.strip():
                        poketext_physiology.append(item.text.strip())
        if poketext_physiology:                
        # we want a new entry for each sentence.
            poketext_physiology = list(filter(None, list(chain(*[text.split('.') for text in poketext_physiology]))))
            temp_physiology_df['Pokemon'] = [pokemon] * len(poketext_physiology)
            temp_physiology_df['physiology'] = poketext_physiology

            physiology_df = pd.concat([physiology_df,temp_physiology_df])
        else:
            print(f'no text found for physiology for {pokemon}')
        # give a second break so the wiki fandom doesn't get sus
        
    except:
        failed_pokemon.append(pokemon)
        f'Found an ERROR for {pokemon}. Added to list'
# Out:
# no text found for behavior for Squirtle
# no text found for behavior for Rattata
# no text found for behavior for Nidoran♀
# no text found for physiology for Nidoran♀
# no text found for behavior for Nidoran♂
# no text found for physiology for Nidoran♂
# no text found for behavior for Zubat
# no text found for behavior for Gloom
# no text found for behavior for Venonat
# no text found for behavior for Venomoth
# no text found for behavior for Poliwag
# no text found for behavior for Bellsprout
# no text found for behavior for Weepinbell
# no text found for behavior for Victreebel
# no text found for behavior for Tentacruel
# no text found for behavior for Graveler
# no text found for behavior for Voltorb
# no text found for behavior for Cubone
# no text found for behavior for Koffing
# no text found for behavior for Rhydon
# no text found for behavior for Goldeen
# no text found for behavior for Seaking
# no text found for behavior for Magmar
# no text found for physiology for Ditto
# no text found for behavior for Eevee
# no text found for behavior for Porygon
# no text found for behavior for Omanyte
# no text found for behavior for Croconaw
# no text found for physiology for Feraligatr
# no text found for physiology for Spinarak
# no text found for behavior for Ariados
# no text found for physiology for Ariados
# no text found for behavior for Pichu
# no text found for physiology for Sudowoodo
# no text found for behavior for Sunflora
# no text found for physiology for Sunflora
# no text found for physiology for Yanma
# no text found for physiology for Wobbuffet
# no text found for behavior for Mantine
# no text found for behavior for Entei
# no text found for behavior for Suicune
# no text found for behavior for Pupitar
# no text found for behavior for Celebi
# no text found for behavior for Cascoon
# no text found for physiology for Cascoon
# no text found for behavior for Taillow
# no text found for behavior for Swellow
# no text found for physiology for Swellow
# no text found for physiology for Ninjask
# no text found for physiology for Makuhita
# no text found for behavior for Mawile
# no text found for physiology for Meditite
# no text found for physiology for Electrike
# no text found for behavior for Volbeat
# no text found for physiology for Volbeat
# no text found for behavior for Roselia
# no text found for behavior for Gulpin
# no text found for behavior for Grumpig
# no text found for behavior for Vibrava
# no text found for physiology for Flygon
# no text found for behavior for Lunatone
# no text found for behavior for Lileep
# no text found for physiology for Lileep
# no text found for behavior for Anorith
# no text found for behavior for Armaldo
# no text found for behavior for Castform
# no text found for behavior for Tropius
# no text found for behavior for Relicanth
# no text found for behavior for Beldum
# no text found for behavior for Latias
# no text found for behavior for Latios
# no text found for behavior for Kyogre
# no text found for behavior for Groudon
# no text found for behavior for Starly
# no text found for physiology for Kricketot
# no text found for physiology for Kricketune
# no text found for physiology for Shieldon
# no text found for physiology for Bastiodon
# no text found for behavior for Mothim
# no text found for behavior for Floatzel
# no text found for physiology for Ambipom
# no text found for physiology for Bonsly
# no text found for behavior for Spiritomb
# no text found for behavior for Skorupi
# no text found for behavior for Porygon-Z
# no text found for behavior for Dusknoir
# no text found for behavior for Uxie
# no text found for behavior for Mesprit
# no text found for behavior for Azelf
# no text found for behavior for Palkia
# no text found for behavior for Phione
# no text found for behavior for Manaphy
# no text found for behavior for Arceus
# no text found for behavior for Simipour
# no text found for behavior for Pidove
# no text found for behavior for Throh
# no text found for behavior for Whirlipede
# no text found for behavior for Sandile
# no text found for behavior for Frillish
# no text found for behavior for Klang
# no text found for behavior for Heatmor
# no text found for behavior for Reshiram
# no text found for behavior for Zekrom
# no text found for behavior for Genesect
# no text found for behavior for Fletchinder
# no text found for physiology for Florges
# no text found for behavior for Gogoat
# no text found for behavior for Amaura
# no text found for behavior for Xerneas
# no text found for physiology for Comfey
# no text found for physiology for Wimpod
# no text found for behavior for Solgaleo
# no text found for behavior for Lunala
# no text found for behavior for Nihilego
# no text found for behavior for Pheromosa
# no text found for behavior for Kartana
# no text found for physiology for Gossifleur
# no text found for physiology for Rolycoly
# no text found for physiology for Duraludon
# no text found for behavior for Eternatus
# no text found for behavior for Crocalor
# no text found for behavior for Tarountula
# no text found for behavior for Spidops
# no text found for physiology for Spidops
# no text found for behavior for Nymble
# no text found for physiology for Nymble
# no text found for behavior for Pawmo
# no text found for behavior for Pawmot
# no text found for behavior for Dachsbun
# no text found for behavior for Dolliv
# no text found for behavior for Arboliva
# no text found for behavior for Naclstack
# no text found for behavior for Garganacl
# no text found for physiology for Garganacl
# no text found for behavior for Tadbulb
# no text found for physiology for Tadbulb
# no text found for physiology for Wattrel
# no text found for physiology for Kilowattrel
# no text found for behavior for Maschiff
# no text found for physiology for Maschiff
# no text found for behavior for Shroodle
# no text found for physiology for Shroodle
# no text found for physiology for Brambleghast
# no text found for physiology for Toedscool
# no text found for behavior for Flittle
# no text found for physiology for Flittle
# no text found for behavior for Sandy Shocks
# no text found for physiology for Sandy Shocks
# no text found for behavior for Iron Treads
# no text found for physiology for Iron Treads
# no text found for behavior for Iron Bundle
# no text found for physiology for Iron Bundle
# no text found for behavior for Iron Hands
# no text found for physiology for Iron Hands
# no text found for behavior for Iron Jugulis
# no text found for physiology for Iron Jugulis
# no text found for behavior for Iron Moth
# no text found for physiology for Iron Moth
# no text found for behavior for Iron Thorns
# no text found for physiology for Iron Thorns
# no text found for behavior for Frigibax
# no text found for physiology for Frigibax
# no text found for behavior for Arctibax
# no text found for physiology for Arctibax
# no text found for behavior for Wo-Chien
# no text found for behavior for Ting-Lu
# no text found for behavior for Chi-Yu
# no text found for behavior for Iron Valiant
# no text found for physiology for Iron Valiant
# no text found for behavior for Koraidon
# no text found for behavior for Miraidon

# %%
behavior_df
# Out:
#        Pokemon                                           Behavior
# 0    Bulbasaur  A Bulbasaur often rests in bright places so it...
# 1    Bulbasaur          It can be seen napping in bright sunlight
# 2    Bulbasaur   While it sleeps, the seed on its back catches...
# 3    Bulbasaur  In the wild, Bulbasaur tend to be very rare, a...
# 4    Bulbasaur   However, they are also generally very docile,...
# ..         ...                                                ...
# 0   Baxcalibur  Best seen when using its signature move, Glaiv...
# 1   Baxcalibur   It then finishes off its opponent with a sing...
# 0    Gholdengo  Gholdengo has a friendly disposition and can b...
# 0    Chien-Pao  Chien-Pao is described as being able to contro...
# 1    Chien-Pao                   It is known as the Sword of Ruin
#
# [5521 rows x 2 columns]

# %% [markdown]
# Now, let's drop the scraped parts that don't make any sense.

# %%
display(physiology_df[(physiology_df.physiology.str.len() < 10)])
display(behavior_df[(behavior_df.Behavior.str.len() < 20)])

physiology_df = physiology_df[~(physiology_df.physiology.str.len() < 10)]
behavior_df = behavior_df[~(behavior_df.Behavior.str.len() < 20)]
# Out:
#       Pokemon physiology
# 4      Staryu          "
# 5     Lanturn          "
# 9    Qwilfish          "
# 5     Exploud          )
# 4     Cradily          ﻿
# 8      Latias        [1]
# 1   Magnezone          F
# 2   Magnezone          O
# 2      Phione       8lbs
# 8     Panpour          ﻿
# 6   Tranquill        [1]
# 15    Sandile          "
# 4    Guzzlord          "
# 9    Overqwil          "
#        Pokemon            Behavior
# 12    Raticate   Their webbed feet
# 6     Magneton              radius
# 2      Dratini   5 feet (2 meters)
# 3     Ampharos   On the other hand
# 8      Murkrow                   ”
# 1     Qwilfish    6 gallons/approx
# 5     Delibird             Everest
# 6     Swampert              waters
# 4     Clamperl                   ”
# 1    Infernape   It never gives up
# 8       Piplup                  36
# 10  Kricketune                   ”
# 4     Salazzle                   ”
# 1    Naganadel  7 kilometers) away
# 5      Milcery                   g
# 2     Alcremie                 [1]
# 3      Wiglett                ​[1]
# 3    Farigiraf               ​​[1]

# %%
behavior_df.to_csv('behavior_df.csv')
physiology_df.to_csv('physiology_df.csv')
